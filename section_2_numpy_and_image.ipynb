# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import skimage as ski
from PIL import Image
import numpy as np

# %%
# pic = Image.open("images/coins.jpeg")

pic = ski.data.cat()
pic = pic.astype(np.uint8)

# %%
type(pic)
# Out:
# numpy.ndarray

# %%
plt.imshow(pic)
